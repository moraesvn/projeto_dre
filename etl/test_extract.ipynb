# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from extract import extract_dre_xlsx
from transform import limpar_espacos, converter_meses_para_float, padronizar_nomes_colunas, remover_coluna_total

# %%
df = extract_dre_xlsx('dre_2020_gp_sp.xlsx')

# %%
df = padronizar_nomes_colunas(df)

# %%
df = converter_meses_para_float(df)

# %%
df = limpar_espacos(df)

# %%
df = remover_coluna_total(df)

# %%
display(df[:60])
# Out:
#                             descricao  janeiro  fevereiro    marco    abril  \
# 0                       RECEITA BRUTA  5333.79    2436.90  1425.17  6420.99
# 1                       Notas Fiscais  5333.79    2436.90  1425.17  6420.99
# 2                       Notas Servico     0.00       0.00     0.00     0.00
# 3                          Quantidade    18.00       7.00    15.00    27.00
# 4                        Ticket medio   296.32     348.13    95.01   237.81
# 5                            DEDUCOES  2067.39     848.38   643.65  1609.88
# 6                          Devolucoes     0.00       0.00     0.00     0.00
# 7                            Impostos   532.58     279.32   187.91   620.13
# 8                                ICMS    45.36      52.68    67.29    51.96
# 9                                  IR     0.00       0.00     0.00     0.00
# 10                                IPI     0.00       0.00     0.00     0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   descricao  74 non-null     object
#  1   janeiro    73 non-null     float64
#  2   fevereiro  73 non-null     float64
#  3   marco      73 non-null     float64
#  4   abril      73 non-null     float64
#  5   maio       73 non-null     float64
#  6   junho      73 non-null     float64
#  7   julho      73 non-null     float64
#  8   agosto     73 non-null     float64
#  9   setembro   73 non-null     float64
#  10  outubro    73 non-null     float64
#  11  novembro   73 non-null     float64
#  12  dezembro   73 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 7.6+ KB
